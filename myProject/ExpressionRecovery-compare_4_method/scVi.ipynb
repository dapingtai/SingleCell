# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import rpy2.robjects as robjects
from rpy2.robjects import r, pandas2ri
from rpy2.robjects.packages import importr
from scvi.dataset import Dataset10X, GeneExpressionDataset

# %%
pandas2ri.activate()

# %%
readRDS = robjects.r["readRDS"]
scdata = readRDS("/mnt/isilonX200/scRNA/Project_1/Result/CL10.merge.noc.Rds")

# %%
robjects.r["str"](scdata)
# Out:
# Formal class 'Seurat' [package "Seurat"] with 12 slots
#   ..@ assays      :List of 2
#   .. ..$ logCPM:Formal class 'Assay' [package "Seurat"] with 8 slots
#   .. .. .. ..@ counts       :Formal class 'dgCMatrix' [package "Matrix"] with 6 slots
#   .. .. .. .. .. ..@ i       : int [1:75732549] 2 8 9 13 14 18 20 22 24 26 ...
#   .. .. .. .. .. ..@ p       : int [1:14163] 0 5160 11462 17126 23536 29978 36325 42384 47428 53524 ...
#   .. .. .. .. .. ..@ Dim     : int [1:2] 18890 14162
#   .. .. .. .. .. ..@ Dimnames:List of 2
#   .. .. .. .. .. .. ..$ : chr [1:18890] "AL627309.1" "AL669831.5" "LINC00115" "FAM41C" ...
#   .. .. .. .. .. .. ..$ : chr [1:14162] "AAACCTGAGGATATAC-CL1-0-P-4" "AAACCTGAGGGTCTCC-CL1-0-P-4" "AAACCTGCACATTTCT-CL1-0-P-4" "AAACGGGGTCCCTACT-CL1-0-P-4" ...
#   .. .. .. .. .. ..@ x       : num [1:75732549] 1 2 1 43 13 8 1 5 2 1 ...
#   .. .. .. .. .. ..@ factors : list()
#   .. .. .. ..@ data         :Formal class 'dgCMatrix' [package "Matrix"] with 6 slots
# ...

# %%
robjects.r["head(scdata@meta.data)"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-e5daf5f5fdcf> in <module>
# ----> 1 robjects.r["head(scdata@meta.data)"]
#
# /usr/lib64/python3.6/site-packages/rpy2/robjects/__init__.py in __getitem__(self, item)
#     394
#     395     def __getitem__(self, item):
# --> 396         res = _globalenv.find(item)
#     397         res = conversion.rpy2py(res)
#     398         if hasattr(res, '__rname__'):
#
# /usr/lib64/python3.6/site-packages/rpy2/rinterface_lib/conversion.py in _(*args, **kwargs)
#      42 def _cdata_res_to_rinterface(function):
#      43     def _(*args, **kwargs):
# ---> 44         cdata = function(*args, **kwargs)
#      45         # TODO: test cdata is of the expected CType
#      46         return _cdata_to_rinterface(cdata)
#
# /usr/lib64/python3.6/site-packages/rpy2/rinterface_lib/_rinterface_capi.py in _(*args, **kwargs)
# ...

# %%
pandas2ri.activate()
r.data()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-8c1ee261f08b> in <module>
# ----> 1 robjects.r["scdata[[]]"]
#
# /usr/lib64/python3.6/site-packages/rpy2/robjects/__init__.py in __getitem__(self, item)
#     394
#     395     def __getitem__(self, item):
# --> 396         res = _globalenv.find(item)
#     397         res = conversion.rpy2py(res)
#     398         if hasattr(res, '__rname__'):
#
# /usr/lib64/python3.6/site-packages/rpy2/rinterface_lib/conversion.py in _(*args, **kwargs)
#      42 def _cdata_res_to_rinterface(function):
#      43     def _(*args, **kwargs):
# ---> 44         cdata = function(*args, **kwargs)
#      45         # TODO: test cdata is of the expected CType
#      46         return _cdata_to_rinterface(cdata)
#
# /usr/lib64/python3.6/site-packages/rpy2/rinterface_lib/_rinterface_capi.py in _(*args, **kwargs)
# ...

# %%
import magic
import pandas as pd
import matplotlib.pyplot as plt
X = pd.read_csv("/home/woror000/MAGIC/data/test_data.csv")
magic_operator = magic.MAGIC()
X_magic = magic_operator.fit_transform(X, genes=['VIM', 'CDH1', 'ZEB1'])
plt.scatter(X_magic['VIM'], X_magic['CDH1'], c=X_magic['ZEB1'], s=1, cmap='inferno')
plt.show()
magic.plot.animate_magic(X, gene_x='VIM', gene_y='CDH1', gene_color='ZEB1', operator=magic_operator)
# Out:
# Calculating MAGIC...
#   Running MAGIC on 500 cells and 197 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.15 seconds.
#     Calculating KNN search...
# /usr/lib/python3.6/site-packages/magic/magic.py:472: UserWarning: Input matrix contains unexpressed genes. Please remove them prior to running MAGIC.
#   "Input matrix contains unexpressed genes. "
#     Calculated KNN search in 0.05 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.05 seconds.
#   Calculated graph and diffusion operator in 0.27 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.28 seconds.
# /usr/lib/python3.6/site-packages/graphtools/graphs.py:293: RuntimeWarning: Detected zero distance between 20 pairs of samples. Consider removing duplicates to avoid errors in downstream processing.
#   RuntimeWarning,
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# ...

# %%
X = pd.read_csv("/home/scrna/MAGIC/data/test_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-17ee51084915> in <module>
# ----> 1 X = pd.read_csv("/home/scrna/MAGIC/data/test_data.csv")
#
# /usr/lib64/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
import os 
os.getcwd()
# Out:
# '/home/woror000/Project/Training/R/Singal_Cell/ExpressionRecovery'
